# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddhantGodwani/Computer-Vision-/blob/main/2_HOG_descriptor_computation_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt

# %%
img = imread('diamond.png')
plt.axis("off")
plt.imshow(img)
print(img.shape)
# Out:
# (389, 204, 4)

# %%
resized_img = resize(img, (128*4, 64*4))
plt.axis("off")
plt.imshow(resized_img)
print(resized_img.shape)
# Out:
# (512, 256, 4)

# %%
fd, hog_image = hog(resized_img,
                    orientations=9,
                    pixels_per_cell=(8,8),
                    cells_per_block=(2, 2),
                    visualize=True,
                    multichannel=True)
plt.axis("off")
plt.imshow(hog_image, cmap="gray")
plt.show()
# Out:
# <ipython-input-6-41a15bf45c3f>:1: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   fd, hog_image = hog(resized_img,
